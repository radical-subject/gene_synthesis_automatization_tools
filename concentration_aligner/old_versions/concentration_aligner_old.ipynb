# %%
"""
maximum availible volume to pool into
"""
max_volume=500

"""
maximum availible volume to be taken out of well
"""
max_oligo_volume=80

"""
maximum availible volume to be taken out of well
"""
min_oligo_volume=5

# """
# target moles of oligo pmol
# """
# target_quantity=90

# %%
df
# Out:
#    where   code length                                                seq  \
# 0     F1   Tr-1  #= 48  GAT TAT GAC ATC CCG ACG ACG GAA AAC CTG TAT TT...
# 1     G1   Tr-2  #= 40  GGC ATC ACC TCC GCG CTG CAC CGT GCA GCC GAC TG...
# 2     H1   Tr-3  #= 44  AAT CTG TGT TCT CTT CGG CAG CCC TGG GTG ATC CA...
# 3     I1   Tr-4  #= 45  GCA CGT CTC GTT AAT GTG GCA GCA CAG CTC GCG AA...
# 4     J1   Tr-5  #= 48  AAA AGC ATT ACG ATT TCC AGC GAA GGC TCA AAA GC...
# ..   ...    ...    ...                                                ...
# 59    A5  Tr-60  #= 44  TTG CCT TTA TCC AGG TAG CCC AAA AGT TGG CAT TC...
# 60    B5  Tr-61  #= 44  TGT ACG CCC ACT GCA ACG AAC CCG CTT TCT CTT TA...
# 61    C5  Tr-62  #= 46  CCG GTA CGT TTA GAG TCC ATA AAG CCA CCA AGG CG...
# 62    D5  Tr-63  #= 40  CGC CTC CCA GCC CTC CCA CAG TGC ACC CCA GCT TG...
# 63    E5  Tr-64  #= 63  GAT CTT AAT ACC CTG CGC CAT CAG ATC TTT TGC TG...
#
#    monoisotopic_mass Nucleic Acid(ng/uL) pM/mkl  pmol   mkl A260/A280  \
# 0           14769,52             306,999  20,79  9,83  0,47     1,966
# 1           12204,81             171,764  14,07  9,83  0,70     1,738
# 2           13481,63             200,742  14,89  9,83  0,66     1,706
# 3           13876,91             133,745   9,64  9,83  1,02     1,863
# 4           14907,62             285,986  19,18  9,83  0,51     2,063
# ..               ...                 ...    ...   ...   ...       ...
# 59          13529,68             271,374  20,06  9,83  0,49     1,769
# 60          13345,56             190,864  14,30  9,83  0,69     1,656
# 61          14098,07                32,6   2,31  9,83  4,25      1,97
# 62          12043,73             173,099  14,37  9,83  0,68      1,64
# 63          19283,36              89,801   4,66  9,83  2,11     1,779
#
#    A260/A230      COMMENT      DMT
# 0      1,123  TRANSPOSASE  DMT OFF
# 1      0,968  TRANSPOSASE  DMT OFF
# 2      1,164  TRANSPOSASE  DMT OFF
# 3      1,002  TRANSPOSASE  DMT OFF
# 4      1,178  TRANSPOSASE  DMT OFF
# ..       ...          ...      ...
# 59      1,23  TRANSPOSASE  DMT OFF
# 60     1,024  TRANSPOSASE  DMT OFF
# 61     0,934  TRANSPOSASE  DMT OFF
# 62     0,842  TRANSPOSASE  DMT OFF
# 63      1,11  TRANSPOSASE  DMT OFF
#
# [64 rows x 13 columns]

# %%
EXPERIMENT_NAME = "OVFF354"
# reading file
import pandas as pd
df_calculated =  pd.read_csv(f'./content/{EXPERIMENT_NAME}_calculated.csv', delimiter='\t', decimal=".")

df = pd.read_csv(f'./content/{EXPERIMENT_NAME}_concentrations.csv', delimiter='\t', decimal=".")

"""
strip the text everywhere on data frame
"""
cols = df.select_dtypes(object).columns
df[cols] = df[cols].apply(lambda x: x.str.strip())
"""
and again
"""
cols = df_calculated.select_dtypes(object).columns
df_calculated[cols] = df_calculated[cols].apply(lambda x: x.str.strip())

"""
now merge cleaned dataframes
"""
merge = pd.merge(df, df_calculated, on='where', how='inner', suffixes=('', '_drop'))
#Drop the duplicate columns
merge.drop([col for col in merge.columns if 'drop' in col], axis=1, inplace=True)

df = merge

df.to_csv(f'./content/{EXPERIMENT_NAME}_merged_input.csv', encoding='UTF8')

# %%
df
# Out:
#    where   code length                                                seq  \
# 0     F1   Tr-1  #= 48  GAT TAT GAC ATC CCG ACG ACG GAA AAC CTG TAT TT...
# 1     G1   Tr-2  #= 40  GGC ATC ACC TCC GCG CTG CAC CGT GCA GCC GAC TG...
# 2     H1   Tr-3  #= 44  AAT CTG TGT TCT CTT CGG CAG CCC TGG GTG ATC CA...
# 3     I1   Tr-4  #= 45  GCA CGT CTC GTT AAT GTG GCA GCA CAG CTC GCG AA...
# 4     J1   Tr-5  #= 48  AAA AGC ATT ACG ATT TCC AGC GAA GGC TCA AAA GC...
# ..   ...    ...    ...                                                ...
# 59    A5  Tr-60  #= 44  TTG CCT TTA TCC AGG TAG CCC AAA AGT TGG CAT TC...
# 60    B5  Tr-61  #= 44  TGT ACG CCC ACT GCA ACG AAC CCG CTT TCT CTT TA...
# 61    C5  Tr-62  #= 46  CCG GTA CGT TTA GAG TCC ATA AAG CCA CCA AGG CG...
# 62    D5  Tr-63  #= 40  CGC CTC CCA GCC CTC CCA CAG TGC ACC CCA GCT TG...
# 63    E5  Tr-64  #= 63  GAT CTT AAT ACC CTG CGC CAT CAG ATC TTT TGC TG...
#
#     monoisotopic_mass  Nucleic Acid(ng/uL)     pM/mkl  pmol   mkl  A260/A280  \
# 0            14769.52              306.999  20.785984  9.83  0.47      1.966
# 1            12204.81              171.764  14.073468  9.83  0.70      1.738
# 2            13481.63              200.742  14.890039  9.83  0.66      1.706
# 3            13876.91              133.745   9.637953  9.83  1.02      1.863
# 4            14907.62              285.986  19.183880  9.83  0.51      2.063
# ..                ...                  ...        ...   ...   ...        ...
# 59           13529.68              271.374  20.057681  9.83  0.49      1.769
# 60           13345.56              190.864  14.301685  9.83  0.69      1.656
# 61           14098.07               32.600   2.312373  9.83  4.25      1.970
# 62           12043.73              173.099  14.372541  9.83  0.68      1.640
# 63           19283.36               89.801   4.656917  9.83  2.11      1.779
#
#     A260/A230      COMMENT      DMT
# 0       1.123  TRANSPOSASE  DMT OFF
# 1       0.968  TRANSPOSASE  DMT OFF
# 2       1.164  TRANSPOSASE  DMT OFF
# 3       1.002  TRANSPOSASE  DMT OFF
# 4       1.178  TRANSPOSASE  DMT OFF
# ..        ...          ...      ...
# 59      1.230  TRANSPOSASE  DMT OFF
# 60      1.024  TRANSPOSASE  DMT OFF
# 61      0.934  TRANSPOSASE  DMT OFF
# 62      0.842  TRANSPOSASE  DMT OFF
# 63      1.110  TRANSPOSASE  DMT OFF
#
# [64 rows x 13 columns]

# %%
# df['Nucleic Acid(ng/uL)'] = df['Nucleic Acid(ng/uL)'].str.replace(',','.').astype(float)
# df['monoisotopic_mass'] = df['monoisotopic_mass'].str.replace(',','.').astype(float)

for i in df.columns:
    try:
        df[i] = df[i].str.replace(',', '.').astype(float)
    except:
        pass
    
df['monoisotopic_mass'] = df['monoisotopic_mass'].astype(float)
df["pM/mkl"] = 1000*df['Nucleic Acid(ng/uL)']/df['monoisotopic_mass']
df=df.dropna()

# if target_quantity/min(df["pM/mkl"]) > 70:
#   print("ATTENTION! target quantity cannot be achieved - oligo concentration is too low!")
#   target_quantity=min(df["pM/mkl"])*30
#   print(f"target_quantity is set to {target_quantity:.2f} pmol instead.")

# df['mkl']=target_quantity/df["pM/mkl"]

# # if sum(df['mkl']) > 500 mkl:
# # if min(df['mkl']) < 0.2 mkl:

# df = df[df['seq'].notna()]
# volume_list = df['mkl'].to_list()

df
# Out:
#    where   code length                                                seq  \
# 0     F1   Tr-1  #= 48  GAT TAT GAC ATC CCG ACG ACG GAA AAC CTG TAT TT...
# 1     G1   Tr-2  #= 40  GGC ATC ACC TCC GCG CTG CAC CGT GCA GCC GAC TG...
# 2     H1   Tr-3  #= 44  AAT CTG TGT TCT CTT CGG CAG CCC TGG GTG ATC CA...
# 3     I1   Tr-4  #= 45  GCA CGT CTC GTT AAT GTG GCA GCA CAG CTC GCG AA...
# 4     J1   Tr-5  #= 48  AAA AGC ATT ACG ATT TCC AGC GAA GGC TCA AAA GC...
# ..   ...    ...    ...                                                ...
# 59    A5  Tr-60  #= 44  TTG CCT TTA TCC AGG TAG CCC AAA AGT TGG CAT TC...
# 60    B5  Tr-61  #= 44  TGT ACG CCC ACT GCA ACG AAC CCG CTT TCT CTT TA...
# 61    C5  Tr-62  #= 46  CCG GTA CGT TTA GAG TCC ATA AAG CCA CCA AGG CG...
# 62    D5  Tr-63  #= 40  CGC CTC CCA GCC CTC CCA CAG TGC ACC CCA GCT TG...
# 63    E5  Tr-64  #= 63  GAT CTT AAT ACC CTG CGC CAT CAG ATC TTT TGC TG...
#
#     monoisotopic_mass  Nucleic Acid(ng/uL)     pM/mkl  pmol   mkl  A260/A280  \
# 0            14769.52              306.999  20.785984  9.83  0.47      1.966
# 1            12204.81              171.764  14.073468  9.83  0.70      1.738
# 2            13481.63              200.742  14.890039  9.83  0.66      1.706
# 3            13876.91              133.745   9.637953  9.83  1.02      1.863
# 4            14907.62              285.986  19.183880  9.83  0.51      2.063
# ..                ...                  ...        ...   ...   ...        ...
# 59           13529.68              271.374  20.057681  9.83  0.49      1.769
# 60           13345.56              190.864  14.301685  9.83  0.69      1.656
# 61           14098.07               32.600   2.312373  9.83  4.25      1.970
# 62           12043.73              173.099  14.372541  9.83  0.68      1.640
# 63           19283.36               89.801   4.656917  9.83  2.11      1.779
#
#     A260/A230      COMMENT      DMT
# 0       1.123  TRANSPOSASE  DMT OFF
# 1       0.968  TRANSPOSASE  DMT OFF
# 2       1.164  TRANSPOSASE  DMT OFF
# 3       1.002  TRANSPOSASE  DMT OFF
# 4       1.178  TRANSPOSASE  DMT OFF
# ..        ...          ...      ...
# 59      1.230  TRANSPOSASE  DMT OFF
# 60      1.024  TRANSPOSASE  DMT OFF
# 61      0.934  TRANSPOSASE  DMT OFF
# 62      0.842  TRANSPOSASE  DMT OFF
# 63      1.110  TRANSPOSASE  DMT OFF
#
# [64 rows x 13 columns]

# %%
# df = pd.read_csv(f'./content/{EXPERIMENT_NAME}_concentrations.csv', delimiter=';', decimal=".")
# df.columns = df.columns.str.strip()
# df_calculated["where"] = df_calculated["where"].str.strip()
# merge = df.merge(df_calculated, on='where')
# merge

# %%
# df_calculated.tail(3)

# %%
# pd.merge(left=df_calculated, right=df, how='inner', on='where')

# %%
# df[df["where"].isin(df_calculated['where'])]

# %%
# pd.set_option('max.rows', 500)

# %%
# df_calculated.columns

# %%
# df_calculated.loc[269, 'where']

# %%
# df.loc[16, 'where']

# %%
# for elem in df_calculated["where"].unique():
#     print(repr(elem))

# %% [markdown]
# <font color='red'>NOTICE ME</font>
#
# Bad data with space `^`
#
# Чтобы такого избежать, лучше при чтении таблиц указывать тип данных для каждого из столбцов (если заранее известно их чисо и тд)
#
# ---

# %%
# df = pd.read_csv(f'./content/{EXPERIMENT_NAME}_concentrations.csv', delimiter=';', decimal=".")
# merge = df.merge(df_calculated, on='where')
# merge

# %%
# df_calculated.merge(df, on="where")

# %%
# df_calculated.head(3)

# %%
df
# Out:
#    where   code length                                                seq  \
# 0     F1   Tr-1  #= 48  GAT TAT GAC ATC CCG ACG ACG GAA AAC CTG TAT TT...
# 1     G1   Tr-2  #= 40  GGC ATC ACC TCC GCG CTG CAC CGT GCA GCC GAC TG...
# 2     H1   Tr-3  #= 44  AAT CTG TGT TCT CTT CGG CAG CCC TGG GTG ATC CA...
# 3     I1   Tr-4  #= 45  GCA CGT CTC GTT AAT GTG GCA GCA CAG CTC GCG AA...
# 4     J1   Tr-5  #= 48  AAA AGC ATT ACG ATT TCC AGC GAA GGC TCA AAA GC...
# ..   ...    ...    ...                                                ...
# 59    A5  Tr-60  #= 44  TTG CCT TTA TCC AGG TAG CCC AAA AGT TGG CAT TC...
# 60    B5  Tr-61  #= 44  TGT ACG CCC ACT GCA ACG AAC CCG CTT TCT CTT TA...
# 61    C5  Tr-62  #= 46  CCG GTA CGT TTA GAG TCC ATA AAG CCA CCA AGG CG...
# 62    D5  Tr-63  #= 40  CGC CTC CCA GCC CTC CCA CAG TGC ACC CCA GCT TG...
# 63    E5  Tr-64  #= 63  GAT CTT AAT ACC CTG CGC CAT CAG ATC TTT TGC TG...
#
#     monoisotopic_mass  Nucleic Acid(ng/uL)     pM/mkl  pmol   mkl  A260/A280  \
# 0            14769.52              306.999  20.785984  9.83  0.47      1.966
# 1            12204.81              171.764  14.073468  9.83  0.70      1.738
# 2            13481.63              200.742  14.890039  9.83  0.66      1.706
# 3            13876.91              133.745   9.637953  9.83  1.02      1.863
# 4            14907.62              285.986  19.183880  9.83  0.51      2.063
# ..                ...                  ...        ...   ...   ...        ...
# 59           13529.68              271.374  20.057681  9.83  0.49      1.769
# 60           13345.56              190.864  14.301685  9.83  0.69      1.656
# 61           14098.07               32.600   2.312373  9.83  4.25      1.970
# 62           12043.73              173.099  14.372541  9.83  0.68      1.640
# 63           19283.36               89.801   4.656917  9.83  2.11      1.779
#
#     A260/A230      COMMENT      DMT
# 0       1.123  TRANSPOSASE  DMT OFF
# 1       0.968  TRANSPOSASE  DMT OFF
# 2       1.164  TRANSPOSASE  DMT OFF
# 3       1.002  TRANSPOSASE  DMT OFF
# 4       1.178  TRANSPOSASE  DMT OFF
# ..        ...          ...      ...
# 59      1.230  TRANSPOSASE  DMT OFF
# 60      1.024  TRANSPOSASE  DMT OFF
# 61      0.934  TRANSPOSASE  DMT OFF
# 62      0.842  TRANSPOSASE  DMT OFF
# 63      1.110  TRANSPOSASE  DMT OFF
#
# [64 rows x 13 columns]

# %%
# pool_1 = "TdT-"
# pool_2 = "p03_F2-"
# pool_3 = "p10_F1-"
# pool_4 = "p10_F2-"
pool_1 = "Tr-"
# pool_2 = "Unnamedsequence_F2-"
# pool_3 = "Unnamedsequence_F3-"


POOL_NAME=pool_1

df = df[df["code"].str.contains(f'^{POOL_NAME}\d+')]
df
# Out:
#    where   code length                                                seq  \
# 0     F1   Tr-1  #= 48  GAT TAT GAC ATC CCG ACG ACG GAA AAC CTG TAT TT...
# 1     G1   Tr-2  #= 40  GGC ATC ACC TCC GCG CTG CAC CGT GCA GCC GAC TG...
# 2     H1   Tr-3  #= 44  AAT CTG TGT TCT CTT CGG CAG CCC TGG GTG ATC CA...
# 3     I1   Tr-4  #= 45  GCA CGT CTC GTT AAT GTG GCA GCA CAG CTC GCG AA...
# 4     J1   Tr-5  #= 48  AAA AGC ATT ACG ATT TCC AGC GAA GGC TCA AAA GC...
# ..   ...    ...    ...                                                ...
# 59    A5  Tr-60  #= 44  TTG CCT TTA TCC AGG TAG CCC AAA AGT TGG CAT TC...
# 60    B5  Tr-61  #= 44  TGT ACG CCC ACT GCA ACG AAC CCG CTT TCT CTT TA...
# 61    C5  Tr-62  #= 46  CCG GTA CGT TTA GAG TCC ATA AAG CCA CCA AGG CG...
# 62    D5  Tr-63  #= 40  CGC CTC CCA GCC CTC CCA CAG TGC ACC CCA GCT TG...
# 63    E5  Tr-64  #= 63  GAT CTT AAT ACC CTG CGC CAT CAG ATC TTT TGC TG...
#
#     monoisotopic_mass  Nucleic Acid(ng/uL)     pM/mkl  pmol   mkl  A260/A280  \
# 0            14769.52              306.999  20.785984  9.83  0.47      1.966
# 1            12204.81              171.764  14.073468  9.83  0.70      1.738
# 2            13481.63              200.742  14.890039  9.83  0.66      1.706
# 3            13876.91              133.745   9.637953  9.83  1.02      1.863
# 4            14907.62              285.986  19.183880  9.83  0.51      2.063
# ..                ...                  ...        ...   ...   ...        ...
# 59           13529.68              271.374  20.057681  9.83  0.49      1.769
# 60           13345.56              190.864  14.301685  9.83  0.69      1.656
# 61           14098.07               32.600   2.312373  9.83  4.25      1.970
# 62           12043.73              173.099  14.372541  9.83  0.68      1.640
# 63           19283.36               89.801   4.656917  9.83  2.11      1.779
#
#     A260/A230      COMMENT      DMT
# 0       1.123  TRANSPOSASE  DMT OFF
# 1       0.968  TRANSPOSASE  DMT OFF
# 2       1.164  TRANSPOSASE  DMT OFF
# 3       1.002  TRANSPOSASE  DMT OFF
# 4       1.178  TRANSPOSASE  DMT OFF
# ..        ...          ...      ...
# 59      1.230  TRANSPOSASE  DMT OFF
# 60      1.024  TRANSPOSASE  DMT OFF
# 61      0.934  TRANSPOSASE  DMT OFF
# 62      0.842  TRANSPOSASE  DMT OFF
# 63      1.110  TRANSPOSASE  DMT OFF
#
# [64 rows x 13 columns]

# %%
"""
смотрим распределение по корзинам
"""
ax = df['pM/mkl'].plot.hist(bins=12, alpha=0.5)
initial_oligos_concentrations = df['pM/mkl']
ax.set_xlabel("pmol/mkl")
ax.set_ylabel("occurencies")
# Out:
# Text(0, 0.5, 'occurencies')

# %%
'''
определяем выбросы
'''
import pandas
import numpy as np
from scipy import stats

# %reload_ext google.colab.data_table

df['score'] = np.abs(stats.zscore(df['pM/mkl']))<1.8
# df[(np.abs(stats.zscore(df)) < 1.5).all(axis=1)]
filtered, filtered_off = (df[(np.abs(stats.zscore(df['pM/mkl'])) < 1.8)], df[(np.abs(stats.zscore(df['pM/mkl'])) >= 1.8)])
filtered_off
# Out:
#    where   code length                                                seq  \
# 25    O2  Tr-26  #= 41  TCT GTT GCA GCT GCG TGA GAG CTT TAC CCC ACC GC...
# 29    C3  Tr-30  #= 41  GTT CGT TGC AGT GGG CGT ACA TGG CGA TTG CGC GC...
# 31    E3  Tr-32  #= 44  TGT GGG AGG GCT GGG AGG CGC TGC AAT CGA AAC TG...
# 35    I3  Tr-36  #= 49  CCT TCG CTG GAA ATC GTA ATG CTT TTA CCC GAA TA...
# 61    C5  Tr-62  #= 46  CCG GTA CGT TTA GAG TCC ATA AAG CCA CCA AGG CG...
#
#     monoisotopic_mass  Nucleic Acid(ng/uL)     pM/mkl  pmol    mkl  A260/A280  \
# 25           12514.01                8.201   0.655345  9.83  15.00      2.035
# 29           12711.12              309.029  24.311705  9.83   0.40      1.732
# 31           13749.80               23.498   1.708970  9.83   5.75      1.892
# 35           15028.65              369.481  24.585109  9.83   0.40      1.778
# 61           14098.07               32.600   2.312373  9.83   4.25      1.970
#
#     A260/A230      COMMENT      DMT  score
# 25      0.912  TRANSPOSASE  DMT OFF  False
# 29      1.355  TRANSPOSASE  DMT OFF  False
# 31      0.559  TRANSPOSASE  DMT OFF  False
# 35      1.198  TRANSPOSASE  DMT OFF  False
# 61      0.934  TRANSPOSASE  DMT OFF  False

# %%
"""
смотрим распределение по корзинам
"""
ax = filtered['pM/mkl'].plot.hist(bins=12, alpha=0.5)
ax.set_xlabel("pmol/mkl")
ax.set_ylabel("occurencies")
# Out:
# Text(0, 0.5, 'occurencies')

# %%
# """
# split into 7 bins by quantiles
# """
# labels=["1", "2", "3", "4", "5", "6", "7"]
# filtered["quantile"] = pd.qcut(df['pM/mkl'], q=[0, 0.05, 0.1, 0.35, 0.55, 0.9, 0.95, 1], labels=labels)
# seventh_quantile_median_conc = filtered[filtered['quantile'] == "7"]['pM/mkl'].median()
# second_quantile_median_conc = filtered[filtered['quantile'] == "2"]['pM/mkl'].median()
# mkl = round(5*seventh_quantile_median_conc/second_quantile_median_conc)
# mkl

# seventh_quantile_median_conc = filtered[filtered['quantile'] == labels[-1]]['pM/mkl'].median()
# seventh_quantile_median_conc

# %%
"""
split into N bins by quantiles
"""
N = 8

labels=list(np.arange(1, N))
labels = [str(elem) for elem in labels]
q = list(np.linspace(0, 1, N))

filtered["quantile"] = pd.qcut(df['pM/mkl'], q=q, labels=labels)

'''
выравниваем группы концентраций в пределах отличия в 1.5 раз
'''
highest_quantile_median_conc = filtered[filtered['quantile'] == labels[-1]]['pM/mkl'].median()
for i in labels:
    
    i_quantile_median_conc = filtered[filtered['quantile'] == i]['pM/mkl'].median()
    mkl = round(5*highest_quantile_median_conc/i_quantile_median_conc)
    filtered.loc[filtered['quantile'] == i, ['mkl']] = mkl


"""
пересчитываем моли
"""
filtered['pmol'] = filtered['mkl']*filtered['pM/mkl']
median_conc = round(filtered['pM/mkl'].median())
median_moles_in_pool = round(filtered['pmol'].median())
# print(filtered.sort_values('pM/mkl'))
print(f"equalized result: median_moles_in_pool = {median_moles_in_pool}")
filtered
# Out:
# equalized result: median_moles_in_pool = 103
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    where   code length                                                seq  \
# 0     F1   Tr-1  #= 48  GAT TAT GAC ATC CCG ACG ACG GAA AAC CTG TAT TT...
# 1     G1   Tr-2  #= 40  GGC ATC ACC TCC GCG CTG CAC CGT GCA GCC GAC TG...
# 2     H1   Tr-3  #= 44  AAT CTG TGT TCT CTT CGG CAG CCC TGG GTG ATC CA...
# 3     I1   Tr-4  #= 45  GCA CGT CTC GTT AAT GTG GCA GCA CAG CTC GCG AA...
# 4     J1   Tr-5  #= 48  AAA AGC ATT ACG ATT TCC AGC GAA GGC TCA AAA GC...
# 5     K1   Tr-6  #= 46  GCG TAC CGT TTC ATT CGC AAT CCG AAT GTT TCT GC...
# 6     L1   Tr-7  #= 45  GTA AAG CCG GTG CCA TGC AGA CCG TGA AAC TGG CA...
# 7     M1   Tr-8  #= 45  CGG AAC TGT TGG CCA TTG AAG ATA CCA CCT CGC TG...
# 8     N1   Tr-9  #= 49  ATC AGG TCG CAG AAG AGC TGG GCA AAC TGG GTT CA...
# 9     O1  Tr-10  #= 44  GCG TGG CTG GTG GGT TCA CAG TGT TCT GCT TTT GG...
# 10    P1  Tr-11  #= 43  CCT TTC GTA CCG TTG GTC TGC TTC ACC AGG AGT GG...
# 11    A2  Tr-12  #= 47  TCC GGA TGA CCC AGC GGA TGC AGA TGA GAA AGA GT...
# 12    B2  Tr-13  #= 42  TGG CGG CAG CGG CGA CAA GTC GCC TCC GTA TGG GC...
# 13    C2  Tr-14  #= 43  TGA GCA ACG TCA TTG CCG TGT GCG ACC GCG AAG CA...
# 14    D2  Tr-15  #= 45  TGC CTA TCT GCA GGA TAA ACT GGC GCA CAA CGA AC...
# 15    E2  Tr-16  #= 52  TCG TAG CAA ACA TCC ACG TAA AGA TGT GGA ATC GG...
# 16    F2  Tr-17  #= 47  CAC TTG AAG AAC CAA CCG GAA CTC GGC GGC TAC CA...
# 17    G2  Tr-18  #= 48  TCA GAA AGG CGT TGT TGA TAA ACG TGG CAA GCG TA...
# 18    H2  Tr-19  #= 40  ACG TAA AGC GAG CCT GAG CCT GCG TAG TGG TCG CA...
# 19    I2  Tr-20  #= 47  CTT AAA CAA GGC AAT ATT ACA CTG AAT GCG GTG CT...
# 20    J2  Tr-21  #= 42  TAA CCC GCC GAA AGG TGA AAC CCC GCT GAA ATG GC...
# 21    K2  Tr-22  #= 42  GAC CAG CGA ACC AGT GGA ATC ACT TGC GCA GGC AC...
# 22    L2  Tr-23  #= 52  GAT CGA TAT TTA CAC CCA TCG TTG GCG TAT CGA GG...
# 23    M2  Tr-24  #= 40  AAA ACC GGT GCG GGT GCG GAA CGC CAG CGT ATG GA...
# 24    N2  Tr-25  #= 49  CGG ATA ACC TGG AAC GCA TGG TCA GTA TTC TGT CA...
# 26    P2  Tr-27  #= 45  TCC GTG CCC AGG GTC TTC TGA AAG AAG CGG AAC AT...
# 27    A3  Tr-28  #= 40  AGA GCG CCG AAA CCG TTC TGA CCC CGG ACG AAT GC...
# 28    B3  Tr-29  #= 47  TTT GGG CTA CCT GGA TAA AGG CAA GCG CAA ACG TA...
# 30    D3  Tr-31  #= 46  GGC TTT ATG GAC TCT AAA CGT ACC GGC ATT GCA AG...
# 32    F3  Tr-33  #= 44  TGC AGC GCG GAG GTG ATG CCC ATT GCG CCT TGG AA...
# 33    G3  Tr-34  #= 43  GGC TGC CGA AGA GAA CAC AGA TTT GGC CCA GTC GG...
# 34    H3  Tr-35  #= 43  CTG CCA CAT TAA CGA GAC GTG CCG TAC GAC GTG GA...
# 36    J3  Tr-37  #= 45  GGA TTG CGA ATG AAA CGG TAC GCA CCC TCC TGC AT...
# 37    K3  Tr-38  #= 44  TCT GCA TGG CAC CGG CTT TAC GAA TGG CCT CGG CA...
# 38    L3  Tr-39  #= 49  GTA TCT TCA ATG GCC AAC AGT TCC GGA AAC TCT TG...
# 39    M3  Tr-40  #= 42  CCC AGC TCT TCT GCG ACC TGA TGA CGG TAC GAC AG...
# 40    N3  Tr-41  #= 47  TGT GAA CCC ACC AGC CAC GCG ATT TAT CTT GAA TT...
# 41    O3  Tr-42  #= 46  AGC AGA CCA ACG GTA CGA AAG GTC GTT GCT TCC AA...
# 42    P3  Tr-43  #= 41  CAT CCG CTG GGT CAT CCG GAC GCA TCC ACC ACT CC...
# 43    A4  Tr-44  #= 47  ACT TGT CGC CGC TGC CGC CAG CCA TTT ACC AGA CT...
# 44    B4  Tr-45  #= 43  ACA CGG CAA TGA CGT TGC TCA TCA TAG AGC CCA TA...
# 45    C4  Tr-46  #= 46  GCC AGT TTA TCC TGC AGA TAG GCA TGA ATA TCT GC...
# 46    D4  Tr-47  #= 48  ACA TCT TTA CGT GGA TGT TTG CTA CGA ACC ACA AA...
# 47    E4  Tr-48  #= 50  CGA GTT CCG GTT GGT TCT TCA AGT GGT CAT ACA GG...
# 48    F4  Tr-49  #= 48  CAC GTT TAT CAA CAA CGC CTT TCT GAC CAA TGG AG...
# 49    G4  Tr-50  #= 42  GGC TCA GGC TCG CTT TAC GTG CCG GAC GAT TCT TA...
# 50    H4  Tr-51  #= 47  ATT CAG TGT AAT ATT GCC TTG TTT AAG GGT GAT GC...
# 51    I4  Tr-52  #= 42  GGT TTC ACC TTT CGG CGG GTT AAT TTC CTC CGC CA...
# 52    J4  Tr-53  #= 42  TGA TTC CAC TGG TTC GCT GGT CAG CAG CAG CCA TT...
# 53    K4  Tr-54  #= 46  GCC AAC GAT GGG TGT AAA TAT CGA TCA CGC GCA GT...
# 54    L4  Tr-55  #= 46  TCC GCA CCC GCA CCG GTT TTC CAC GCC TTA TGG AA...
# 55    M4  Tr-56  #= 42  ACC ATG CGT TCC AGG TTA TCC GGC TCT TCC ATA CG...
# 56    N4  Tr-57  #= 48  CTC TCA CGC AGC TGC AAC AGA CGA ACC GCA ACA AA...
# 57    O4  Tr-58  #= 40  CAG AAG ACC CTG GGC ACG GAG GGC CTG CGG TGG GG...
# 58    P4  Tr-59  #= 45  CAG AAC GGT TTC GGC GCT CTG ACT TTC GAC ATG TT...
# 59    A5  Tr-60  #= 44  TTG CCT TTA TCC AGG TAG CCC AAA AGT TGG CAT TC...
# 60    B5  Tr-61  #= 44  TGT ACG CCC ACT GCA ACG AAC CCG CTT TCT CTT TA...
# 62    D5  Tr-63  #= 40  CGC CTC CCA GCC CTC CCA CAG TGC ACC CCA GCT TG...
# 63    E5  Tr-64  #= 63  GAT CTT AAT ACC CTG CGC CAT CAG ATC TTT TGC TG...
#
#     monoisotopic_mass  Nucleic Acid(ng/uL)     pM/mkl        pmol   mkl  \
# 0            14769.52              306.999  20.785984  103.929918   5.0
# 1            12204.81              171.764  14.073468   98.514274   7.0
# 2            13481.63              200.742  14.890039  104.230275   7.0
# 3            13876.91              133.745   9.637953   96.379525  10.0
# 4            14907.62              285.986  19.183880  115.103283   6.0
# 5            14043.01              202.618  14.428388  100.998718   7.0
# 6            13903.95              247.743  17.818174  106.909044   6.0
# 7            13772.84              176.981  12.850000  115.650004   9.0
# 8            15186.80              277.291  18.258685  109.552111   6.0
# 9            13665.75              216.449  15.838794   95.032764   6.0
# 10           13248.47              146.136  11.030406   99.273652   9.0
# 11           14626.41              253.226  17.312929  103.877575   6.0
# 12           12972.31              154.381  11.900810  107.107292   9.0
# 13           13252.53              215.129  16.233051   97.398308   6.0
# 14           13860.91              213.414  15.396825   92.380948   6.0
# 15           16051.33              281.866  17.560289  105.361736   6.0
# 16           14402.27              112.296   7.797104  101.362355  13.0
# 17           14905.59              171.523  11.507294  103.565642   9.0
# 18           12306.91              217.182  17.647159  105.882955   6.0
# 19           14584.41              150.452  10.315947  103.159470  10.0
# 20           12893.30              150.768  11.693515  105.241637   9.0
# 21           12934.31              176.105  13.615338   95.307365   7.0
# 22           16058.32              264.937  16.498426   98.990554   6.0
# 23           12470.02              111.302   8.925567   89.255671  10.0
# 24           15124.70              145.804   9.640125   96.401251  10.0
# 26           13894.94              270.694  19.481480  116.888882   6.0
# 27           12244.89              244.999  20.008265  100.041323   5.0
# 28           14643.45              288.418  19.696042   98.480208   5.0
# 30           14206.12              268.965  18.933037  113.598224   6.0
# 32           13628.74              234.025  17.171433  103.028600   6.0
# 33           13303.54              101.579   7.635486   99.261324  13.0
# 34           13182.48              152.694  11.583101  104.247911   9.0
# 36           13836.89              148.937  10.763763  107.637627  10.0
# 37           13492.67              244.752  18.139627  108.837762   6.0
# 38           15022.65              202.325  13.467997   94.275977   7.0
# 39           12916.28              230.653  17.857541  107.145246   6.0
# 40           14373.25              118.112   8.217487  106.827336  13.0
# 41           14179.16              139.478   9.836831   98.368310  10.0
# 42           12483.00              250.172  20.041016  100.205079   5.0
# 43           14228.12              244.088  17.155323  102.931940   6.0
# 44           13246.53              145.581  10.990123  109.901235  10.0
# 45           14132.07              312.463  22.110207  110.551037   5.0
# 46           14748.48              344.691  23.371290  116.856449   5.0
# 47           15367.86              200.545  13.049637  117.446736   9.0
# 48           14687.45              130.958   8.916320   89.163197  10.0
# 49           12864.23              141.678  11.013329   99.119963   9.0
# 50           14483.32              215.371  14.870278  104.091949   7.0
# 51           12784.18              168.434  13.175190  118.576710   9.0
# 52           12897.27              178.815  13.864562   97.051934   7.0
# 53           14209.13               93.974   6.613635   85.977255  13.0
# 54           13932.94              242.014  17.369916  104.219497   6.0
# 55           12808.21              230.888  18.026563  108.159376   6.0
# 56           14701.50              127.337   8.661497   86.614971  10.0
# 57           12502.02              100.836   8.065577  104.852496  13.0
# 58           13735.80              103.998   7.571310   98.427030  13.0
# 59           13529.68              271.374  20.057681  100.288403   5.0
# 60           13345.56              190.864  14.301685  100.111797   7.0
# 62           12043.73              173.099  14.372541  100.607785   7.0
# 63           19283.36               89.801   4.656917   60.539916  13.0
#
#     A260/A280  A260/A230      COMMENT      DMT  score quantile
# 0       1.966      1.123  TRANSPOSASE  DMT OFF   True        7
# 1       1.738      0.968  TRANSPOSASE  DMT OFF   True        4
# 2       1.706      1.164  TRANSPOSASE  DMT OFF   True        4
# 3       1.863      1.002  TRANSPOSASE  DMT OFF   True        2
# 4       2.063      1.178  TRANSPOSASE  DMT OFF   True        6
# 5       1.743      1.131  TRANSPOSASE  DMT OFF   True        4
# 6       1.926      1.153  TRANSPOSASE  DMT OFF   True        6
# 7       1.777      1.121  TRANSPOSASE  DMT OFF   True        3
# 8       2.051      1.166  TRANSPOSASE  DMT OFF   True        6
# 9       1.820      1.373  TRANSPOSASE  DMT OFF   True        5
# 10      1.725      1.280  TRANSPOSASE  DMT OFF   True        3
# 11      1.968      1.240  TRANSPOSASE  DMT OFF   True        5
# 12      1.804      1.015  TRANSPOSASE  DMT OFF   True        3
# 13      1.911      1.182  TRANSPOSASE  DMT OFF   True        5
# 14      1.853      1.205  TRANSPOSASE  DMT OFF   True        5
# 15      1.936      1.143  TRANSPOSASE  DMT OFF   True        5
# 16      1.862      1.080  TRANSPOSASE  DMT OFF   True        1
# 17      1.740      0.967  TRANSPOSASE  DMT OFF   True        3
# 18      1.814      1.069  TRANSPOSASE  DMT OFF   True        6
# 19      2.042      1.227  TRANSPOSASE  DMT OFF   True        2
# 20      1.818      1.053  TRANSPOSASE  DMT OFF   True        3
# 21      1.891      1.073  TRANSPOSASE  DMT OFF   True        4
# 22      1.915      1.343  TRANSPOSASE  DMT OFF   True        5
# 23      1.966      1.178  TRANSPOSASE  DMT OFF   True        2
# 24      1.785      1.350  TRANSPOSASE  DMT OFF   True        2
# 26      1.870      1.142  TRANSPOSASE  DMT OFF   True        6
# 27      1.842      0.901  TRANSPOSASE  DMT OFF   True        7
# 28      2.070      1.182  TRANSPOSASE  DMT OFF   True        7
# 30      1.830      1.239  TRANSPOSASE  DMT OFF   True        6
# 32      1.850      0.393  TRANSPOSASE  DMT OFF   True        5
# 33      1.838      1.111  TRANSPOSASE  DMT OFF   True        1
# 34      1.852      1.099  TRANSPOSASE  DMT OFF   True        3
# 36      1.799      1.154  TRANSPOSASE  DMT OFF   True        2
# 37      1.835      1.102  TRANSPOSASE  DMT OFF   True        6
# 38      1.784      1.154  TRANSPOSASE  DMT OFF   True        4
# 39      1.778      1.151  TRANSPOSASE  DMT OFF   True        6
# 40      1.793      1.120  TRANSPOSASE  DMT OFF   True        1
# 41      2.029      1.077  TRANSPOSASE  DMT OFF   True        2
# 42      1.732      0.986  TRANSPOSASE  DMT OFF   True        7
# 43      1.670      1.022  TRANSPOSASE  DMT OFF   True        5
# 44      1.901      0.975  TRANSPOSASE  DMT OFF   True        2
# 45      1.702      0.958  TRANSPOSASE  DMT OFF   True        7
# 46      1.850      1.200  TRANSPOSASE  DMT OFF   True        7
# 47      1.800      1.153  TRANSPOSASE  DMT OFF   True        3
# 48      1.819      1.028  TRANSPOSASE  DMT OFF   True        2
# 49      1.693      1.161  TRANSPOSASE  DMT OFF   True        3
# 50      1.922      1.042  TRANSPOSASE  DMT OFF   True        4
# 51      1.645      1.127  TRANSPOSASE  DMT OFF   True        3
# 52      1.749      1.136  TRANSPOSASE  DMT OFF   True        4
# 53      1.939      1.203  TRANSPOSASE  DMT OFF   True        1
# 54      1.710      1.035  TRANSPOSASE  DMT OFF   True        5
# 55      1.723      1.073  TRANSPOSASE  DMT OFF   True        6
# 56      1.988      1.039  TRANSPOSASE  DMT OFF   True        2
# 57      1.884      1.259  TRANSPOSASE  DMT OFF   True        1
# 58      1.653      1.151  TRANSPOSASE  DMT OFF   True        1
# 59      1.769      1.230  TRANSPOSASE  DMT OFF   True        7
# 60      1.656      1.024  TRANSPOSASE  DMT OFF   True        4
# 62      1.640      0.842  TRANSPOSASE  DMT OFF   True        4
# 63      1.779      1.110  TRANSPOSASE  DMT OFF   True        1

# %%
filtered_off['mkl'] = median_moles_in_pool/filtered_off['pM/mkl']
filtered_off.loc[filtered_off['mkl'] >= max_oligo_volume, ['mkl']] = max_oligo_volume
filtered_off.loc[filtered_off['mkl'] <= min_oligo_volume, ['mkl']] = min_oligo_volume
filtered_off['mkl'] = round(filtered_off['mkl'])
filtered_off
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#    where   code length                                                seq  \
# 25    O2  Tr-26  #= 41  TCT GTT GCA GCT GCG TGA GAG CTT TAC CCC ACC GC...
# 29    C3  Tr-30  #= 41  GTT CGT TGC AGT GGG CGT ACA TGG CGA TTG CGC GC...
# 31    E3  Tr-32  #= 44  TGT GGG AGG GCT GGG AGG CGC TGC AAT CGA AAC TG...
# 35    I3  Tr-36  #= 49  CCT TCG CTG GAA ATC GTA ATG CTT TTA CCC GAA TA...
# 61    C5  Tr-62  #= 46  CCG GTA CGT TTA GAG TCC ATA AAG CCA CCA AGG CG...
#
#     monoisotopic_mass  Nucleic Acid(ng/uL)     pM/mkl  pmol   mkl  A260/A280  \
# 25           12514.01                8.201   0.655345  9.83  80.0      2.035
# 29           12711.12              309.029  24.311705  9.83   5.0      1.732
# 31           13749.80               23.498   1.708970  9.83  60.0      1.892
# 35           15028.65              369.481  24.585109  9.83   5.0      1.778
# 61           14098.07               32.600   2.312373  9.83  45.0      1.970
#
#     A260/A230      COMMENT      DMT  score
# 25      0.912  TRANSPOSASE  DMT OFF  False
# 29      1.355  TRANSPOSASE  DMT OFF  False
# 31      0.559  TRANSPOSASE  DMT OFF  False
# 35      1.198  TRANSPOSASE  DMT OFF  False
# 61      0.934  TRANSPOSASE  DMT OFF  False

# %%
"""
FINAL CONCATENATION AND VOLUME ASSERTION TEST
"""
result = pd.concat([filtered_off, filtered])
result['pmol'] = result['mkl']*result['pM/mkl']
total = result['mkl'].sum()
result['final conc, pmol/mkl'] = round(result['pmol']/total, 2)
print(f"calculated total volume of pool: {total} mkl")
# assert total < total_volume, "max volume exceeded"

'''
если пул больше max_volume (500 мкл) - разбиваем на столько пробирок, сколько потребуется
'''
pool_index_list = []
sum = 0
for i in result['mkl']:
  sum+=i
  pool_index_list+=[round(1+sum//max_volume)]

result['target_well'] = pool_index_list

'''
проверяем, что у нас нет разницы концентраций на порядок
'''
assert min(result['final conc, pmol/mkl'])*10 > max(result['final conc, pmol/mkl']), "разброс концентраций превышает 1 порядок!!!\nЭто непорядок!!!"
"""
если все хорошо - идем дальше
"""
result.sort_index(inplace=True)
result
print(f"разбито на {max(pool_index_list)} пробирки(ок)")
# Out:
# calculated total volume of pool: 663.0 mkl
# разбито на 2 пробирки(ок)

# %%
# """
# FINALWORKLIST EXPORT
# """
# volume_list = round(result['mkl'], 0).astype(int)


# """
# читаем файл из програмы Глеба
# """
# worklist_df = pd.read_csv(f'./content/{EXPERIMENT_NAME}_worklist.csv', delimiter=',', header=None)
# worklist_df.reset_index(drop=True)
# # drop NaN seq
# worklist_df[4] = volume_list
# worklist_df[4] = worklist_df[4]
# worklist_df[4]
# worklist_df[3] = pool_index_list

# """
# экспортируем новый worklist
# """
# worklist_df.to_csv(f'./content/{EXPERIMENT_NAME}_equalized_conc_worklist.csv', encoding='UTF8')

# final_equalized_oligo_concentration=median_moles_in_pool/worklist_df[4].sum()
# total_volume=worklist_df[4].sum()


# print(f"final_equalized_oligo_concentration = ~{final_equalized_oligo_concentration:.3f} pmol/mkl")
# print(f"total_volume = {total_volume:.1f} mkl")
# print(f"minimal taken volume = {min(worklist_df[4]):.2f} mkl")
# print(f"max taken volume = {max(worklist_df[4]):.2f} mkl")
# print(f"max разброс финальных концентраций = {100*(max(result['final conc, pmol/mkl'])-min(result['final conc, pmol/mkl']))/(result['final conc, pmol/mkl'].mean()):.2f}% или в {2*(max(result['final conc, pmol/mkl'])-min(result['final conc, pmol/mkl']))/(result['final conc, pmol/mkl'].mean()):.2f} раз")
# print(f"среднее значение концентраций {result['final conc, pmol/mkl'].mean():.3f}±{result['final conc, pmol/mkl'].std():.3f} pmol/mkl")

# %%
"""
FINALWORKLIST EXPORT
"""
volume_list = round(result['mkl'], 0).astype(int)
number_of_wells = len(volume_list)

def coordinate_to_number_parser(list_of_coords):
    '''
    переводит координату на плашке из формата A1 в порядковый номер
    '''
    index_list = []
    for i in list_of_coords: 
        
        row = ord(i[0]) - 64
        column = int(i[1:])
        index_list += [16*(column-1)+row]
    
    return index_list

list_of_indexes = coordinate_to_number_parser(result["where"].to_list())

col1 = ["384well"]*number_of_wells
col2 = list_of_indexes
col3 = ["96well"]*number_of_wells
col4 = pool_index_list
col5 = volume_list.to_list()

list_of_lists = [col1, col2, col3, col4, col5]

worklist_df = pd.DataFrame(list_of_lists)
worklist_df = worklist_df.reset_index(drop=True)
worklist_df = worklist_df.T

"""
экспортируем новый worklist
"""
worklist_df.to_csv(f'./content/{EXPERIMENT_NAME}_equalized_conc_worklist_{POOL_NAME}.csv', encoding='UTF8', header=None, index=False)


"""
SOME METADATA
"""
final_equalized_oligo_concentration=median_moles_in_pool/worklist_df[4].sum()
total_volume=worklist_df[4].sum()


print(f"final_equalized_oligo_concentration = ~{final_equalized_oligo_concentration:.3f} pmol/mkl")
print(f"total_volume = {total_volume:.1f} mkl")
print(f"minimal taken volume = {min(worklist_df[4]):.2f} mkl")
print(f"max taken volume = {max(worklist_df[4]):.2f} mkl")
print(f"max разброс финальных концентраций = {100*(max(result['final conc, pmol/mkl'])-min(result['final conc, pmol/mkl']))/(result['final conc, pmol/mkl'].mean()):.2f}% или в {2*(max(result['final conc, pmol/mkl'])-min(result['final conc, pmol/mkl']))/(result['final conc, pmol/mkl'].mean()):.2f} раз")
print(f"среднее значение концентраций {result['final conc, pmol/mkl'].mean():.3f}±{result['final conc, pmol/mkl'].std():.3f} pmol/mkl")
# Out:
# final_equalized_oligo_concentration = ~0.155 pmol/mkl
# total_volume = 663.0 mkl
# minimal taken volume = 5.00 mkl
# max taken volume = 80.00 mkl
# max разброс финальных концентраций = 71.26% или в 1.43 раз
# среднее значение концентраций 0.154±0.018 pmol/mkl

# %%
result.to_csv(f'./content/{EXPERIMENT_NAME}_result.csv', encoding='UTF8')

# %%
"""
смотрим распределение по корзинам
"""
ax = result['final conc, pmol/mkl'].plot.hist(bins=5, alpha=0.5)
ax.set_xlabel("pmol/mkl")
ax.set_ylabel("occurencies")
# Out:
# Text(0, 0.5, 'occurencies')

# %%
comparison_df = pd.DataFrame([initial_oligos_concentrations, result['final conc, pmol/mkl']]).T
comparison_df["unaligned"] = comparison_df["pM/mkl"]/comparison_df["pM/mkl"].median()
comparison_df["aligned"] = comparison_df['final conc, pmol/mkl']/comparison_df['final conc, pmol/mkl'].median()
comparison_df = comparison_df[["aligned", "unaligned"]]
comparison_df = comparison_df.melt(var_name='groups', value_name='normalized molar concentrations')

import seaborn as sns

ax = sns.violinplot(x = "groups", y="normalized molar concentrations", data=comparison_df, color='r', alpha = 0.1)

# %% [markdown]
# Сравниваем 4 эксперимента
#  - с выравниванием и без + эти два с очисткой на магнитных частицах
#  - Как сравнивать?
#      - смотреть распределение продуктов на капиллярном форезе
#      - по интенсивности на форезе при одинаковом количестве циклов
#      - на риалтаймнике
#  - Можно ли одновременно на риалтаймнике?

# %%
np.linspace(0, 1, 21)
# Out:
# array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#        0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ])
